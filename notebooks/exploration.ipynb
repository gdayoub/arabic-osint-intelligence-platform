# %% [markdown]
# # Arabic OSINT Exploration Notebook\n\nUse this notebook for ad-hoc EDA on `raw_articles` and `processed_articles`.

# %%
import pandas as pd\nfrom sqlalchemy import create_engine\n\nengine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/arabic_osint')\ndf = pd.read_sql('SELECT * FROM raw_articles LIMIT 20', engine)\ndf.head()
